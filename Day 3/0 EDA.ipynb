# %% [markdown]
# # Example of EDA
# ### in Databricks Notebooks

# %%
# %pip install sweetviz ydata-profiling[notebook] plotly hvplot numba
# %restart_python

# %%
spark_df = spark.table("dwx_express_insights_platform_dev_working.db_crash_course.inspection_gold")
spark_df = spark_df.withColumnRenamed("count", "inspection_count")
df = spark_df.toPandas()

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, explorative=True)
displayHTML(str(profile.to_html()))

# %%
import sweetviz as sv
sv.analyze(df).show_notebook()

# %%
import plotly.express as px
px.scatter_matrix(df.select_dtypes("number"))

# %%
display(spark_df)
# Out:
# Databricks data profile. Run in Databricks to view.
